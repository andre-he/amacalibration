# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

import report

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['figure.figsize']=(12,8)
matplotlib.rcParams['legend.fontsize']=20

# %%
pre_reports = []
letters = ['A', 'B']
nums = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11']
for l in letters: 
    for n in nums: 
        try: 
            r = report.Report('AMAC_' + l + n)
            pre_reports.append(r)
            print r.name
            r.render_genparam()
        except AttributeError: 
            print 'DataFrame object has no attribute VCC_H'
            continue
reports = report.Reports(pre_reports)
# Out:
# AMAC_A01
# ...

# %%
print reports.genparam
# Out:
#                  Param         val        stddev      AMAC  VCC_H
# 0    current_1V5_Reset    0.038304  4.301210e-05  AMAC_A01    1.5
# 1            VDD_Reset    1.294060  1.554310e-15  AMAC_A01    1.5
# 2      current_1V5_Run    0.028772  2.925500e-03  AMAC_A01    1.5
# 3              VDD_Run    1.187880  1.143740e-03  AMAC_A01    1.5
# 4              VDD_2_R  538.900000  3.000000e-01  AMAC_A01    1.5
# 5              VDD_2_L  499.000000  0.000000e+00  AMAC_A01    1.5
# 6               DVDD_2  588.000000  0.000000e+00  AMAC_A01    1.5
# 7                   BG  525.000000  0.000000e+00  AMAC_A01    1.5
# 8                 Temp  543.000000  0.000000e+00  AMAC_A01    1.5
# 9              VDD_H_4  332.000000  0.000000e+00  AMAC_A01    1.5
# 10               OTA_R  752.600000  4.898980e-01  AMAC_A01    1.5
# 11               OTA_L  700.700000  4.582580e-01  AMAC_A01    1.5
# 12   current_1V5_Reset    0.038058  1.777090e-03  AMAC_A01    2.0
# ...

# %%
print "Params" 
genparam_hist = pd.DataFrame.hist(reports.genparam, 'val', 'Param', grid=True, xlabelsize=None, xrot=None, ylabelsize=None, yrot=None, ax=None, sharex=False, sharey=False, figsize=(40,30), layout=None, bins=20)
# Out:
# Params

# %%
print reports.i2c
# Out:
#         VCC_H  I2C_SuccessRate      AMAC
# 0    0.650350             0.00  AMAC_A01
# 1    0.700320             1.00  AMAC_A01
# 2    0.750291             1.00  AMAC_A01
# 3    0.800262             1.00  AMAC_A01
# 4    0.850232             1.00  AMAC_A01
# 5    0.900203             1.00  AMAC_A01
# 6    0.950174             1.00  AMAC_A01
# 7    1.000140             1.00  AMAC_A01
# 8    1.050120             1.00  AMAC_A01
# 9    1.100090             1.00  AMAC_A01
# 10   1.150060             1.00  AMAC_A01
# 11   1.200030             1.00  AMAC_A01
# 12   1.250580             1.00  AMAC_A01
# 13   1.300550             1.00  AMAC_A01
# 14   1.350520             1.00  AMAC_A01
# 15   1.400490             1.00  AMAC_A01
# 16   1.450460             1.00  AMAC_A01
# 17   1.500430             1.00  AMAC_A01
# 18   1.550400             1.00  AMAC_A01
# 19   1.600370             1.00  AMAC_A01
# 20   1.650340             1.00  AMAC_A01
# 21   1.700320             1.00  AMAC_A01
# ...

# %%
genI2C_hist = pd.DataFrame.hist(reports.i2c, 'I2C_SuccessRate', 'VCC_H', grid=True, xlabelsize=None, xrot=None, ylabelsize=None, yrot=None, ax=None, sharex=False, sharey=False, figsize=(40,30), layout=None, bins=10)

# %%
bp_i2c = reports.i2c.boxplot('I2C_SuccessRate', 'VCC_H', fontsize=12, figsize=(50, 30))
